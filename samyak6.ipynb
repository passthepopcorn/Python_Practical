# %% [markdown]
# <a href="https://colab.research.google.com/github/passthepopcorn/Python_Practical/blob/main/samyak6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. Write a Python program to find those numbers which are divisible by 7 and multiple of 5,
# between 1500 and 2700 (both included)

# %%
1. #Read data
import pandas as pd
data=pd.read_csv("IMDB-Movie-Data.csv")
data
# Out:
#      Rank                    Title                     Genre  \
# 0       1  Guardians of the Galaxy   Action,Adventure,Sci-Fi
# 1       2               Prometheus  Adventure,Mystery,Sci-Fi
# 2       3                    Split           Horror,Thriller
# 3       4                     Sing   Animation,Comedy,Family
# 4       5            Suicide Squad  Action,Adventure,Fantasy
# ..    ...                      ...                       ...
# 995   996     Secret in Their Eyes       Crime,Drama,Mystery
# 996   997          Hostel: Part II                    Horror
# 997   998   Step Up 2: The Streets       Drama,Music,Romance
# 998   999             Search Party          Adventure,Comedy
# 999  1000               Nine Lives     Comedy,Family,Fantasy
#
#                                            Description              Director  \
# 0    A group of intergalactic criminals are forced ...            James Gunn
# ...

# %% [markdown]
# 2. View the data: do a quick preview of the data by using appropriate methods

# %%
#2. View the data: do a quick preview of the data by using appropriate methods
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Title               1000 non-null   object
#  2   Genre               1000 non-null   object
#  3   Description         1000 non-null   object
#  4   Director            1000 non-null   object
#  5   Actors              1000 non-null   object
#  6   Year                1000 non-null   int64
#  7   Runtime (Minutes)   1000 non-null   int64
#  8   Rating              1000 non-null   float64
#  9   Votes               1000 non-null   int64
#  10  Revenue (Millions)  872 non-null    float64
#  11  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 93.9+ KB

# %% [markdown]
# 3. Understand some basic information about the data: Use appropriate functions to understand
# the shape, number of columns, indexes, and other information and description about the
# dataframe. Write some observations from the information you see

# %%
data.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)   Metascore
# count          872.000000  936.000000
# mean            82.956376   58.985043
# std            103.253540   17.194757
# min              0.000000   11.000000
# 25%             13.270000   47.000000
# ...

# %%
data.shape
# Out:
# (1000, 12)

# %%
data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %% [markdown]
# 4. Data Selection – Indexing and Slicing data:
#
# a. Extract ‘Genre’ data from the dataframe; as a series and as a data frame

# %%
df=data[['Genre']]
df
# Out:
#                         Genre
# 0     Action,Adventure,Sci-Fi
# 1    Adventure,Mystery,Sci-Fi
# 2             Horror,Thriller
# 3     Animation,Comedy,Family
# 4    Action,Adventure,Fantasy
# ..                        ...
# 995       Crime,Drama,Mystery
# 996                    Horror
# 997       Drama,Music,Romance
# 998          Adventure,Comedy
# 999     Comedy,Family,Fantasy
#
# [1000 rows x 1 columns]

# %% [markdown]
# b. Extract multiple columns from the data frame

# %%
multi_columns=data[['Title','Genre','Director','Actors']]
multi_columns
# Out:
#                        Title                     Genre              Director  \
# 0    Guardians of the Galaxy   Action,Adventure,Sci-Fi            James Gunn
# 1                 Prometheus  Adventure,Mystery,Sci-Fi          Ridley Scott
# 2                      Split           Horror,Thriller    M. Night Shyamalan
# 3                       Sing   Animation,Comedy,Family  Christophe Lourdelet
# 4              Suicide Squad  Action,Adventure,Fantasy            David Ayer
# ..                       ...                       ...                   ...
# 995     Secret in Their Eyes       Crime,Drama,Mystery             Billy Ray
# 996          Hostel: Part II                    Horror              Eli Roth
# 997   Step Up 2: The Streets       Drama,Music,Romance            Jon M. Chu
# 998             Search Party          Adventure,Comedy        Scot Armstrong
# 999               Nine Lives     Comedy,Family,Fantasy      Barry Sonnenfeld
#
# ...

# %% [markdown]
# c. Display the title revenue and rating for data in rows 10 to 15

# %%
#c. Display the title revenue and rating for data in rows 10 to 15
result = data[['Title','Revenue (Millions)','Rating']].iloc[10:15]
result
# Out:
#                                       Title  Revenue (Millions)  Rating
# 10  Fantastic Beasts and Where to Find Them              234.02     7.5
# 11                           Hidden Figures              169.27     7.8
# 12                                Rogue One              532.17     7.9
# 13                                    Moana              248.75     7.7
# 14                                 Colossal                2.87     6.4

# %% [markdown]
# d. Display the Genre, Actors, Directors, Rating, Revenue for movie ‘Suicide Squad’/ or of
# your choice

# %%
dis=data[['Title','Genre','Actors','Director','Rating','Revenue (Millions)']]
res=dis[(dis['Title']=='Suicide Squad')]
res
# Out:
#            Title                     Genre  \
# 4  Suicide Squad  Action,Adventure,Fantasy
#
#                                               Actors    Director  Rating  \
# 4  Will Smith, Jared Leto, Margot Robbie, Viola D...  David Ayer     6.2
#
#    Revenue (Millions)
# 4              325.02
